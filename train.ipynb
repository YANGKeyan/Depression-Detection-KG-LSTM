# %%
# !python main.py --epoch 100 --lr 2e-5 --train_data_path dataset/train.tsv --test_data_path dataset/test.tsv --txt_embedding_path dataset/glove.6B.300d.txt --cpt_embedding_path dataset/glove.6B.300d.txt  --embedding_dim 300 --train_batch_size 64 --hidden_size 128
# Out:
# 06/07/2023 12:35:17 - INFO - torchtext.vocab -  Loading vectors from .vector_cache/glove.6B.300d.txt.pt
# Vector size of Text Vocabulary:  torch.Size([26206, 300])
# 06/07/2023 12:35:18 - INFO - torchtext.vocab -  Loading vectors from .vector_cache/glove.6B.300d.txt.pt
# Vector size of Concept Vocabulary:  torch.Size([3153, 300])
# /root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:1933: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# 06/07/2023 12:35:23 - INFO - __main__ -  Epoch:0, Idx:0, Training Loss:1.0835
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 22.49it/s]
# /root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
